# %%
import pandas as pd
import numpy as np
from pandas import Timestamp
import datetime as dt
from datetime import datetime
from tool import utils

# %% [markdown]
# ### Loading Data

# %%
# read csv into dataframe, specifying the year
crashes = utils.read_csv_of_year(2022)
crashes.head()
# Out:
#    Unnamed: 0  CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  \
# 0           1  2022-03-26      11:45       NaN       NaN        NaN
# 1           2  2022-06-29       6:55       NaN       NaN        NaN
# 2          34  2022-06-29      16:00       NaN       NaN        NaN
# 3          37  2022-07-12      17:50  BROOKLYN   11225.0  40.663303
# 4          38  2022-03-23      10:00       NaN       NaN        NaN
#
#    LONGITUDE                LOCATION                    ON STREET NAME  \
# 0        NaN                     NaN           QUEENSBORO BRIDGE UPPER
# 1        NaN                     NaN                THROGS NECK BRIDGE
# 2        NaN                     NaN  WILLIAMSBURG BRIDGE OUTER ROADWA
# 3  -73.96049  (40.663303, -73.96049)                               NaN
# 4        NaN                     NaN                               NaN
#
#   CROSS STREET NAME  ... CONTRIBUTING FACTOR VEHICLE 2  \
# 0               NaN  ...                           NaN
# ...

# %%
crashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103787 entries, 0 to 103786
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     103787 non-null  int64
#  1   CRASH DATE                     103787 non-null  object
#  2   CRASH TIME                     103787 non-null  object
#  3   BOROUGH                        68724 non-null   object
#  4   ZIP CODE                       68712 non-null   float64
#  5   LATITUDE                       94849 non-null   float64
#  6   LONGITUDE                      94849 non-null   float64
#  7   LOCATION                       94849 non-null   object
#  8   ON STREET NAME                 75520 non-null   object
#  9   CROSS STREET NAME              48766 non-null   object
#  10  OFF STREET NAME                28265 non-null   object
#  11  NUMBER OF PERSONS INJURED      103787 non-null  float64
# ...

# %% [markdown]
# ### Duplicate Records

# %%
dup_rows = crashes.duplicated().sum()
dup_rows
# Out:
# 0

# %% [markdown]
# ### Consistent Format

# %%
# Convert object to datatime("11:45"+":00")
crashes['CRASH DATE'] = pd.to_datetime(crashes['CRASH DATE'])
crashes['CRASH TIME'] = crashes['CRASH TIME']+':00'
crashes['CRASH TIME'] = pd.to_datetime(crashes['CRASH TIME'],format='%H:%M:%S').dt.time
crashes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# TypeError: unsupported operand type(s) for +: 'datetime.time' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Convert object to datatime("11:45"+":00")
#       2 crashes['CRASH DATE'] = pd.to_datetime(crashes['CRASH DATE'])
# ----> 3 crashes['CRASH TIME'] = crashes['CRASH TIME']+':00'
#       4 crashes['CRASH TIME'] = pd.to_datetime(crashes['CRASH TIME'],format='%H:%M:%S').dt.time
#       5 crashes
#
# ...
